# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd  /content/drive/'My Drive'/NYU_Spring_2021/DLS/rl_rec/Model-Based-Reinforcement-Learning-for-Online-Recommendation-master/simulation_task1
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/NYU_Spring_2021/DLS/rl_rec/Model-Based-Reinforcement-Learning-for-Online-Recommendation-master/simulation_task1

# %%
# !pwd
# Out:
# /content/drive/My Drive/NYU_Spring_2021/DLS/rl_rec/Model-Based-Reinforcement-Learning-for-Online-Recommendation-master/simulation_task1

# %%
# !python Generate_data.py
# Out:
# The original reward is: 1.6371
